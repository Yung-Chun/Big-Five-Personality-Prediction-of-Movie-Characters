# %%
import pandas as pd
import numpy as np
import json
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import re
from pathlib import Path
import os
import time
import yaml
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso
from sklearn.ensemble import VotingClassifier, BaggingRegressor, BaggingClassifier, RandomForestRegressor, RandomForestClassifier, AdaBoostClassifier, AdaBoostRegressor, GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report, precision_score, get_scorer_names, mean_squared_error, r2_score, mean_squared_error, roc_auc_score, ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import train_test_split, LeaveOneOut, cross_val_score, KFold, GridSearchCV
from sklearn.pipeline import Pipeline
from statistics import mean
import warnings
warnings.filterwarnings('ignore')

# %%
training_data_path = Path('training_data')
embedding_path = Path('Movie-Script-Database/scripts/embedding')
model_selection_record_path = Path('model_selection_record')

# %% [markdown]
# ## import training data

# %%
file_name = 'essays_embedding_rmpunc_rmsw'
essays_embedding = pd.read_csv(training_data_path / f'{file_name}.csv', encoding = 'cp1252')

# %%
essays_embedding.head()
# Out:
#    Unnamed: 0          #AUTHID  \
# 0           0  1997_504851.txt
# 1           1  1997_605191.txt
# 2           2  1997_687252.txt
# 3           3  1997_568848.txt
# 4           4  1997_688160.txt
#
#                                                 TEXT  cEXT  cNEU  cAGR  cCON  \
# 0  Well, right now I just woke up from a mid-day ...     0     1     1     0
# 1  Well, here we go with the stream of consciousn...     0     0     1     0
# 2  An open keyboard and buttons to push. The thin...     0     1     0     1
# 3  I can't believe it!  It's really happening!  M...     1     0     1     1
# 4  Well, here I go with the good old stream of co...     1     0     1     0
#
#    cOPN                                         clean_text  \
# 0     1  right woke mid day nap sort weird moved texas ...
# 1     0  stream consciousness essay things like high sc...
# 2     1  open keyboard buttons push thing finally worke...
# 3     0  believe happening pulse racing like mad like f...
# 4     1  good old stream consciousness assignment feel ...
#
#                                 clean_text_embedding
# 0  [-0.0008707201923243701, 0.002650993410497904,...
# 1  [0.001168464426882565, 0.0072226133197546005, ...
# 2  [-0.00998779572546482, 0.0114965895190835, 0.0...
# 3  [-0.02526545524597168, -0.007222685497254133, ...
# 4  [0.00883069634437561, -0.004120076075196266, 0...

# %% [markdown]
# ## import training record

# %%
all_records = pd.DataFrame()

for file in model_selection_record_path.glob(f'*svc_essays_embedding*linear*50*'):
    print(f'opening {file.stem} at {time.ctime()}')

    temp = pd.read_csv(model_selection_record_path / f'{file.stem}.csv')
    temp['file'] = file.stem.split('svc_essays_embedding_')[1]
    all_records = pd.concat([all_records, temp])
    
kernel = file.stem.split('_')[-3]
gamma = file.stem.split('_')[-2]
print(kernel, gamma)
# Out:
# opening svc_essays_embedding_rmpunc_rmsw_cCON_linear_scale_50 at Thu Jan 11 21:43:54 2024
# opening svc_essays_embedding_rmpunc_rmsw_cOPN_linear_scale_50 at Thu Jan 11 21:43:54 2024
# opening svc_essays_embedding_rmpunc_rmsw_cNEU_linear_scale_50 at Thu Jan 11 21:43:54 2024
# opening svc_essays_embedding_rmpunc_rmsw_cEXT_linear_scale_50 at Thu Jan 11 21:43:54 2024
# opening svc_essays_embedding_rmpunc_rmsw_cAGR_linear_scale_50 at Thu Jan 11 21:43:54 2024
# linear scale

# %%
all_records.head()
# Out:
#       y  kernel  gamma         C  mean_train_score  mean_test_score  \
# 0  cCON  linear  scale  1.000000          0.626646         0.558247
# 1  cCON  linear  scale  1.015628          0.626899         0.558247
# 2  cCON  linear  scale  1.031500          0.627153         0.556727
# 3  cCON  linear  scale  1.047621          0.627659         0.556727
# 4  cCON  linear  scale  1.063993          0.628673         0.556221
#
#    score_gap  best_score  best_params                              file
# 0   0.068399    0.558752     1.114661  rmpunc_rmsw_cCON_linear_scale_50
# 1   0.068652    0.558752     1.114661  rmpunc_rmsw_cCON_linear_scale_50
# 2   0.070426    0.558752     1.114661  rmpunc_rmsw_cCON_linear_scale_50
# 3   0.070932    0.558752     1.114661  rmpunc_rmsw_cCON_linear_scale_50
# 4   0.072452    0.558752     1.114661  rmpunc_rmsw_cCON_linear_scale_50

# %%
all_records = all_records.replace('cCON', 'Conscientiousness')\
                            .replace('cEXT', 'Extraversion')\
                            .replace('cNEU', 'Neuroticism')\
                            .replace('cAGR', 'Agreeableness')\
                            .replace('cOPN', 'Openness')

# %%
with open('the_best_params.yaml', 'r') as f:
    best_params = yaml.safe_load(f)
    
best_params
# Out:
# {'Agreeableness': 1.6172438571077898,
#  'Conscientiousness': 1.114661130737398,
#  'Extraversion': 1.830851251413804,
#  'Neuroticism': 1.0975091843604738,
#  'Openness': 2.105064009445578}

# %%
y_cols = best_params.keys()
y_cols
# Out:
# dict_keys(['Agreeableness', 'Conscientiousness', 'Extraversion', 'Neuroticism', 'Openness'])

# %% [markdown]
# ## predict

# %%
def predict_personality(y_col):

    svc = SVC(kernel = kernel,  gamma = gamma, random_state = 42, C = best_params[y_col], probability = True)
    svc.fit(X_train, y_train)
    y_proba = svc.predict_proba(X_test)[:, 1]

    return y_proba

# %%
movie_embedding = []
for file in embedding_path.glob(f'*embedding*'):
#     print(f'opening {file.stem} at {time.ctime()}')
    
    with open(file) as ef:
        data = json.load(ef)
        movie_name = list(data.keys())[0]

        for char in data[movie_name].keys():
            clean_line_embedding = data[movie_name][char]['clean_line_embedding']
            movie_embedding.append([movie_name, char, clean_line_embedding])
            
movie_embedding = pd.DataFrame(movie_embedding, columns=['movie_name', 'char', 'clean_line_embedding'])
print(movie_embedding.shape)
# Out:
# (3279, 3)

# %%
X_train = [
    np.array([float(n) for n in x[1:-2].split(', ')])
    for x in essays_embedding['clean_text_embedding']
]

X_test = [np.array(x) for x in movie_embedding['clean_line_embedding']]

for y_col in y_cols:
    print(f'predicting {y_col} at {time.ctime()}')
    y_train = np.array(essays_embedding[y_col])
    movie_embedding[y_col] = predict_personality(y_col)
        
movie_char_big_five_predict_result = movie_embedding.drop(columns='clean_line_embedding')
movie_char_big_five_predict_result.to_csv('movie_char_big_five_predict_result.csv', index=False)
# Out:
# predicting Agreeableness at Thu Jan 11 21:57:39 2024
# predicting Conscientiousness at Thu Jan 11 21:57:39 2024
# predicting Extraversion at Thu Jan 11 21:57:39 2024
# predicting Neuroticism at Thu Jan 11 21:57:39 2024
# predicting Openness at Thu Jan 11 21:57:39 2024

# %% [markdown]
# ## more organized

# %%
for x in movie_char_big_five_predict_result.movie_name:
    if x.split('-')[-1] == 'The':
        print(x)

# %%
for rows in movie_char_big_five_predict_result.itertuples():
    if rows.movie_name.split('-')[-1] == 'The':
        movie_char_big_five_predict_result.loc[
            rows.Index, 'movie_name'] = movie_char_big_five_predict_result.loc[
                rows.Index, 'movie_name'].replace('-The', '')
        
    movie_char_big_five_predict_result.loc[
            rows.Index, 'movie_name'] = movie_char_big_five_predict_result.loc[
                rows.Index, 'movie_name'].replace('-', ' ')    
    
    movie_char_big_five_predict_result.loc[
            rows.Index, 'char'] = movie_char_big_five_predict_result.loc[
                rows.Index, 'char'].capitalize()

# %%
# 'Avengers The (2012)',
# 'Avventura L (The Adventure)',
# 'Majestic The (The Bijou)'
set(movie_char_big_five_predict_result.movie_name)
# Out:
# {'10 Things I Hate About You',
#  '12 Monkeys',
#  '12 Years a Slave',
#  '12 and Holding',
#  '127 Hours',
#  '1492 Conquest of Paradise',
#  '15 Minutes',
#  '17 Again',
#  '187',
#  '2001 A Space Odyssey',
#  '2012',
#  '28 Days Later',
#  '30 Minutes or Less',
#  '42',
#  '44 Inch Chest',
#  '50 50',
#  '500 Days of Summer',
#  '8MM',
#  'A Few Good Men',
#  'A Most Violent Year',
#  'A Prayer Before Dawn',
#  'A Scanner Darkly',
#  'A Serious Man',
#  'Above the Law',
#  'Absolute Power',
#  'Abyss',
#  'Adaptation',
#  'Adjustment Bureau',
#  'Adventures of Buckaroo Banzai Across the Eighth Dimension',
#  'Affliction',
#  'After School Special',
#  'AfterLife',
#  'Agnes of God',
#  'Airplane',
#  'Airplane 2 The Sequel',
#  'Ali',
#  'Alien 3',
#  'Alien Nation',
#  'Alien vs Predator',
#  'Aliens',
#  'All About Steve',
#  'All the Kings Men',
#  'All the Presidents Men',
#  'Alone in the Dark',
#  'Amadeus',
#  'Amelia',
#  'American',
#  'American Beauty',
#  'American Gangster',
#  'American Graffiti',
#  'American History X',
#  'American Hustle',
#  'American Milkshake',
#  'American Pie',
#  'American President',
#  'American Psycho',
#  'American Shaolin King of Kickboxers II',
#  'American Sniper',
#  'American Splendor',
#  'American Werewolf in London',
#  'Amityville Asylum',
#  'Amour',
#  'An Education',
#  'Analyze That',
#  'Analyze This',
#  'Anastasia',
#  'Angel Eyes',
#  'Anna Karenina',
#  'Annie Hall',
#  'Anniversary Party',
#  'Anonymous',
#  'Antitrust',
#  'Antz',
#  'Apocalypse Now',
#  'April Fools Day',
#  'Apt Pupil',
#  'Arbitrage',
#  'Arcade',
#  'Arctic Blue',
#  'Argo',
#  'Army of Darkness',
#  'Arsenic and Old Lace',
#  'Arthur',
#  'As Good As It Gets',
#  'Assassins',
#  'Assignment',
#  'August Osage County',
#  'Austin Powers International Man of Mystery',
#  'Austin Powers The Spy Who Shagged Me',
#  'Authors Anonymous',
#  'Autumn in New York',
#  'Avatar',
#  'Avengers The (2012)',
#  'Avventura L (The Adventure)',
#  'Awakenings',
#  'Babel',
#  'Bachelor Party',
#  'Back up Plan',
#  'Backdraft',
#  'Bad Boys',
#  'Bad Country',
#  'Bad Day at Black Rock',
#  'Bad Dreams',
#  'Bad Lieutenant',
#  'Bad Santa',
#  'Bad Teacher',
#  'Badlands',
#  'Bamboozled',
#  'Barry Lyndon',
#  'Barton Fink',
#  'Basic',
#  'Basic Instinct',
#  'Basquiat',
#  'Batman',
#  'Batman 2',
#  'Battle Los Angeles',
#  'Battle of Shaker Heights',
#  'Bean',
#  'Beasts of No Nation',
#  'Beasts of the Southern Wild',
#  'Beauty and the Beast',
#  'Beavis and Butt head Do America',
#  'Beginners',
#  'Being Human',
#  'Being John Malkovich',
#  'Being There',
#  'Believer',
#  'Belle',
#  'Beloved',
#  'Best Exotic Marigold Hotel',
#  'Big Blue',
#  'Big Eyes',
#  'Big Fish',
#  'Big Lebowski',
#  'Big Sick',
#  'Big White',
#  'Birdman',
#  'Birds',
#  'Birthday Girl',
#  'BlacKkKlansman',
#  'Black Dahlia',
#  'Black Panther',
#  'Black Rain',
#  'Black Snake Moan',
#  'Black Swan',
#  'Blade',
#  'Blade Runner',
#  'Blade Trinity',
#  'Blind Side',
#  'Bling Ring',
#  'Blood and Wine',
#  'Blow',
#  'Blue Valentine',
#  'Blue Velvet',
#  'Body Heat',
#  'Body of Evidence',
#  'Bodyguard',
#  'Bonfire of the Vanities',
#  'Bonnie and Clyde',
#  'Book of Eli',
#  'Boondock Saints',
#  'Boondock Saints 2 All Saints Day',
#  'Bound',
#  'Bounty Hunter',
#  'Bourne Identity',
#  'Bourne Ultimatum',
#  'Box',
#  'Boxtrolls',
#  'Boyhood',
#  'Braveheart',
#  'Breakdown',
#  'Breakfast Club',
#  'Breaking Away',
#  'Brick',
#  'Bridesmaids',
#  'Bringing Out the Dead',
#  'Broken Arrow',
#  'Broken Embraces',
#  'Brothers Bloom',
#  'Bruce Almighty',
#  'Bull Durham',
#  'Buried',
#  'Burlesque',
#  'Burn After Reading',
#  'Burning Annie',
#  'Butterfly Effect',
#  'Cable Guy',
#  'Candle to Water',
#  'Capote',
#  'Carrie',
#  'Cars 2',
#  'Case 39',
#  'Casino',
#  'Cast Away',
#  'Catch Me If You Can',
#  'Cecil B Demented',
#  'Cedar Rapids',
#  'Cell',
#  'Cellular',
#  'Change Up',
#  'Changeling',
#  'Chaos',
#  'Charade',
#  'Charlies Angels',
#  'Chasing Amy',
#  'Cherry Falls',
#  'Chinatown',
#  'Christ Complex',
#  'Chronicle',
#  'Chronicles of Narnia The Lion the Witch and the Wardrobe',
#  'Cider House Rules',
#  'Cincinnati Kid',
#  'Cirque du Freak The Vampires Assistant',
#  'Citizen Kane',
#  'City of Joy',
#  'Clash of the Titans',
#  'Clerks',
#  'Cliffhanger',
#  'Cobb',
#  'Coco',
#  'Code of Silence',
#  'Cold Mountain',
#  'Collateral Damage',
#  'Colombiana',
#  'Color of Night',
#  'Confessions of a Dangerous Mind',
#  'Confidence',
#  'Cooler',
#  'Coraline',
#  'Coriolanus',
#  'Cradle 2 the Grave',
#  'Crank',
#  'Crash',
#  'Crazy Stupid Love',
#  'Crazylove',
#  'Creation',
#  'Crime Spree',
#  'Croods',
#  'Crouching Tiger Hidden Dragon',
#  'Croupier',
#  'Crow',
#  'Cruel Intentions',
#  'Curious Case of Benjamin Button',
#  'Custody',
#  'Dallas Buyers Club',
#  'Damned United',
#  'Dances with Wolves',
#  'Danish Girl',
#  'Dark City',
#  'Dark Knight Rises',
#  'Dark Star',
#  'Darkman',
#  'Date Night',
#  'Dave Barrys Complete Guide to Guys',
#  'Day of the Dead',
#  'Day the Clown Cried',
#  'Day the Earth Stood Still',
#  'Dead Poets Society',
#  'Deadpool',
#  'Dear White People',
#  'Death at a Funeral',
#  'Death to Smoochy',
#  'Debt',
#  'Deception',
#  'Deep Cover',
#  'Deep Rising',
#  'Deer Hunter',
#  'Defiance',
#  'Departed',
#  'Descendants',
#  'Despicable Me 2',
#  'Detroit Rock City',
#  'Devil Wears Prada',
#  'Devil in a Blue Dress',
#  'Devils Advocate',
#  'Die Hard',
#  'Die Hard 2',
#  'Diner',
#  'Distinguished Gentleman',
#  'Disturbia',
#  'Django Unchained',
#  'Do The Right Thing',
#  'Dog Day Afternoon',
#  'Donnie Brasco',
#  'Doors',
#  'Double Indemnity',
#  'Drag Me to Hell',
#  'Dragonslayer',
#  'Drive',
#  'Drive Angry',
#  'Drop Dead Gorgeous',
#  'Dry White Season A',
#  'Duck Soup',
#  'Dumb and Dumber',
#  'Dune',
#  'Eagle Eye',
#  'Eastern Promises',
#  'Easy A',
#  'Ed TV',
#  'Ed Wood',
#  'Edward Scissorhands',
#  'Eight Legged Freaks',
#  'Election',
#  'Elephant Man',
#  'Elizabeth The Golden Age',
#  'Enough',
#  'Entrapment',
#  'Erin Brockovich',
#  'Escape From LA',
#  'Escape From New York',
#  'Eternal Sunshine of the Spotless Mind',
#  'Even Cowgirls Get the Blues',
#  'Event Horizon',
#  'Ex Machina',
#  'Excalibur',
#  'Extract',
#  'Fabulous Baker Boys',
#  'Face Off',
#  'Fair Game',
#  'Family Man',
#  'Fantastic Four',
#  'Fantastic Mr Fox',
#  'Fargo',
#  'Fast Times at Ridgemont High',
#  'Fatal Instinct',
#  'Fault in Our Stars',
#  'Fear and Loathing in Las Vegas',
#  'Feast',
#  'Ferris Buellers Day Off',
#  'Field of Dreams',
#  'Fifth Element',
#  'Fight Club',
#  'Fighter',
#  'Final Destination',
#  'Final Destination 2',
#  'Finding Nemo',
#  'Five Easy Pieces',
#  'Flash Gordon',
#  'Fletch',
#  'Flight',
#  'Flintstones',
#  'Forrest Gump',
#  'Four Rooms',
#  'Foxcatcher',
#  'Fracture',
#  'Frances',
#  'Freaked',
#  'Freddy vs Jason',
#  'French Connection',
#  'Friday the 13th',
#  'Friday the 13th Part VIII Jason Takes Manhattan',
#  'Fright Night (1985)',
#  'From Dusk Till Dawn',
#  'From Here to Eternity',
#  'Frozen (Disney)',
#  'Frozen River',
#  'Fruitvale Station',
#  'Fugitive',
#  'Funny People',
#  'GI Jane',
#  'GI Joe The Rise of Cobra',
#  'Game',
#  'Game 6',
#  'Gamer',
#  'Gandhi',
#  'Gang Related',
#  'Gangs of New York',
#  'Garden State',
#  'Gattaca',
#  'Get Carter',
#  'Get Low',
#  'Get Out',
#  'Get on Up',
#  'Getaway',
#  'Ghost',
#  'Ghost Rider',
#  'Ghost Ship',
#  'Ghost World',
#  'Ghost and the Darkness',
#  'Ghostbusters',
#  'Ghostbusters 2',
#  'Girl with the Dragon Tattoo',
#  'Gladiator',
#  'Glengarry Glen Gross',
#  'Go',
#  'Godfather',
#  'Godfather Part II',
#  'Godfather Part III',
#  'Gods and Monsters',
#  'Godzilla',
#  'Gone Baby Gone',
#  'Gone in 60 Seconds',
#  'Good Girl',
#  'Good Will Hunting',
#  'Grabbers',
#  'Graduate',
#  'Gran Torino',
#  'Grand Hotel',
#  'Grand Theft Parsons',
#  'Grapes of Wrath',
#  'Gravity',
#  'Great Gatsby',
#  'Green Mile',
#  'Gremlins',
#  'Gremlins 2',
#  'Grifters',
#  'Grosse Point Blank',
#  'Groundhog Day',
#  'Grudge',
#  'Guardians of the Galaxy Vol 2',
#  'Hackers',
#  'Hall Pass',
#  'Halloween',
#  'Hancock',
#  'Hangover',
#  'Hanna',
#  'Hannah and Her Sisters',
#  'Hannibal',
#  'Happy Birthday Wanda June',
#  'Happy Feet',
#  'Hard Rain',
#  'Hard to Kill',
#  'Harold and Kumar Go to White Castle',
#  'Haunting',
#  'Heat',
#  'Heathers',
#  'Heavenly Creatures',
#  'Hebrew Hammer',
#  'Heist',
#  'Hellbound Hellraiser II',
#  'Hellboy',
#  'Hellboy 2 The Golden Army',
#  'Hellraiser',
#  'Hellraiser 3 Hell on Earth',
#  'Hellraiser Deader',
#  'Hellraiser Hellseeker',
#  'Help',
#  'Henry Fool',
#  'Henrys Crime',
#  'Her',
#  'Hes Just Not That Into You',
#  'Hesher',
#  'High Fidelity',
#  'Highlander',
#  'Hills Have Eyes',
#  'His Girl Friday',
#  'Hitchcock',
#  'Hitchhikers Guide to the Galaxy',
#  'Hollow Man',
#  'Honeydripper',
#  'Horrible Bosses',
#  'Horse Whisperer',
#  'Hospital',
#  'Hostage',
#  'Hot Tub Time Machine',
#  'Hotel Rwanda',
#  'House of 1000 Corpses',
#  'How to Train Your Dragon',
#  'How to Train Your Dragon 2',
#  'Hudson Hawk',
#  'Hudsucker Proxy',
#  'Human Nature',
#  'Hunt for Red October',
#  'Hurt Locker',
#  'I Am Number Four',
#  'I Love You Phillip Morris',
#  'I Robot',
#  'I Spit on Your Grave',
#  'I Still Know What You Did Last Summer',
#  'I am Sam',
#  'Ice Storm',
#  'Ides of March',
#  'Ill Do Anything',
#  'Imaginarium of Doctor Parnassus',
#  'In the Bedroom',
#  'In the Loop',
#  'Inception',
#  'Indiana Jones IV',
#  'Indiana Jones and the Last Crusade',
#  'Indiana Jones and the Raiders of the Lost Ark',
#  'Indiana Jones and the Temple of Doom',
#  'Informant',
#  'Inglourious Basterds',
#  'Insider',
#  'Insidious',
#  'Insomnia',
#  'Interstellar',
#  'Interview with the Vampire',
#  'Into the Wild',
#  'Into the Woods',
#  'Intolerable Cruelty',
#  'Inventing the Abbotts',
#  'Invention of Lying',
#  'Invictus',
#  'Iron Lady',
#  'Island',
#  'It',
#  'Italian Job',
#  'Its Complicated',
#  'Its a Wonderful Life',
#  'JFK',
#  'Jacket',
#  'Jackie Brown',
#  'Jacobs Ladder',
#  'Jane Eyre',
#  'Jason X',
#  'Jaws',
#  'Jaws 2',
#  'Jay and Silent Bob Strike Back',
#  'Jennifer Eight',
#  'Jennifers Body',
#  'Jerry Maguire',
#  'Jeux Interdits',
#  'Jimmy and Judy',
#  'John Wick',
#  'Joker',
#  'Judge Dredd',
#  'Juno',
#  'Jurassic Park',
#  'Jurassic Park The Lost World',
#  'Kafka',
#  'Kalifornia',
#  'Kids',
#  'Kids Are All Right',
#  'Kill Your Darlings',
#  'Killing Zoe',
#  'King Kong',
#  'King of Comedy',
#  'Kingdom',
#  'Kings Speech',
#  'Klute',
#  'Knocked Up',
#  'Kramer vs Kramer',
#  'Kundun',
#  'Kung Fu Panda',
#  'LA Confidential',
#  'LEGO Movie',
#  'La La Land',
#  'Labor of Love',
#  'Ladykillers',
#  'Lake Placid',
#  'Larry Crowne',
#  'Last Boy Scout',
#  'Last Chance Harvey',
#  'Last Flight',
#  'Last Samurai',
#  'Last Station',
#  'Last Tango in Paris',
#  'Last of the Mohicans',
#  'Law Abiding Citizen',
#  'Le Diable par la Queue',
#  'Legion',
#  'Les Miserables',
#  'Les Tontons Flingueurs',
#  'Leviathan',
#  'Liar Liar',
#  'Life of David Gale',
#  'Life of Pi',
#  'Light Sleeper',
#  'Limey',
#  'Limitless',
#  'Lincoln',
#  'Lincoln Lawyer',
#  'Little Athens',
#  'Little Men',
#  'Little Nicky',
#  'Living in Oblivion',
#  'Lock Stock and Two Smoking Barrels',
#  'Logan',
#  'Logans Run',
#  'Lone Star',
#  'Long Kiss Goodnight',
#  'Looper',
#  'Lord of Illusions',
#  'Lord of War',
#  'Lord of the Rings Fellowship of the Ring',
#  'Lord of the Rings Return of the King',
#  'Lord of the Rings The Two Towers',
#  'Losers',
#  'Lost Highway',
#  'Lost in Translation',
#  'Love and Basketball',
#  'Machete',
#  'Machine Gun Preacher',
#  'Mad Max 2 The Road Warrior',
#  'Magnolia',
#  'Majestic The (The Bijou)',
#  'Major League',
#  'Malcolm X',
#  'Malibus Most Wanted',
#  'Man On Fire',
#  'Man Trouble',
#  'Man Who Knew Too Much',
#  'Man Who Wasntre',
#  'Man in the Iron Mask',
#  'Man on the Moon',
#  'Manhattan Murder Mystery',
#  'Manhunter',
#  'Margaret',
#  'Margin Call',
#  'Margot at the Wedding',
#  'Mariachi El',
#  'Martha Marcy May Marlene',
#  'Martian',
#  'Marty',
#  'Mask',
#  'Master',
#  'Master and Commander',
#  'Matrix',
#  'Max Payne',
#  'Mean Streets',
#  'Mechanic',
#  'Meet Joe Black',
#  'Megamind',
#  'Memento',
#  'Men Who Stare at Goats',
#  'Men in Black',
#  'Men in Black 3',
#  'Metro',
#  'Miami Vice',
#  'Midnight Cowboy',
#  'Midnight Express',
#  'Midnight in Paris',
#  'Mighty Joe Young',
#  'Mighty Morphin Power Rangers The Movie',
#  'Milk',
#  'Mimic',
#  'Minis First Time',
#  'Mirrors',
#  'Misery',
#  'Mission Impossible',
#  'Mission Impossible II',
#  'Mission to Mars',
#  'Moneyball',
#  'Monkeybone',
#  'Monte Carlo',
#  'Moon',
#  'Moonrise Kingdom',
#  'Moonstruck',
#  'Mr Blandings Builds His Dream House',
#  'Mr Brooks',
#  'Mrs Brown',
#  'Mud',
#  'Mulholland Drive',
#  'Mumford',
#  'Mummy',
#  'Music of the Heart',
#  'Mute Witness',
#  'My Best Friends Wedding',
#  'My Girl',
#  'My Mother Dreams the Satans Disciples in New York',
#  'My Week with Marilyn',
#  'Nashville',
#  'Natural Born Killers',
#  'New York Minute',
#  'Newsies',
#  'Next',
#  'Next Friday',
#  'Next Three Days',
#  'Ni vu ni connu',
#  'Nick of Time',
#  'Nightmare Before Christmas',
#  'Nightmare on Elm Street A',
#  'Nightmare on Elm Street The Final Chapter',
#  'Nine',
#  'Nines',
#  'Ninja Assassin',
#  'Ninotchka',
#  'No Strings Attached',
#  'Notting Hill',
#  'Oblivion',
#  'Observe and Report',
#  'Obsessed',
#  'Oceans Eleven',
#  'Oceans Twelve',
#  'Office Space',
#  'One Flew Over the Cuckoos Nest',
#  'Only God Forgives',
#  'Ordinary People',
#  'Orphan',
#  'Other Boleyn Girl',
#  'Out of Sight',
#  'Pacifier',
#  'Pandorum',
#  'Panic Room',
#  'ParaNorman',
#  'Pariah',
#  'Passengers',
#  'Patriot',
#  'Paul',
#  'Peeping Tom',
#  'Peggy Sue Got Married',
#  'Perfect Creature',
#  'Perfect World A',
#  'Perks of Being a Wallflower',
#  'Pet Sematary',
#  'Pet Sematary II',
#  'Petulia',
#  'Philadelphia',
#  'Phone Booth',
#  'Pi',
#  'Pianist',
#  'Piano',
#  'Pineapple Express',
#  'Pirates of the Caribbean',
#  'Pirates of the Caribbean Dead Mans Chest',
#  'Pitch Black',
#  'Pleasantville',
#  'Point Break',
#  'Postman',
#  'Power of One',
#  'Precious',
#  'Predator',
#  'Prestige',
#  'Pretty Woman (final script)',
#  'Pride and Prejudice',
#  'Priest',
#  'Princess Bride',
#  'Private Life of Sherlock Holmes',
#  'Producer',
#  'Program',
#  'Prom Night',
#  'Prometheus',
#  'Prophecy',
#  'Proposal',
#  'Psycho',
#  'Public Enemies',
#  'Pulp Fiction',
#  'Purple Rain',
#  'Queen',
#  'Queen of the Damned',
#  'RKO 281',
#  'Rachel Getting Married',
#  'Raging Bull',
#  'Raising Arizona',
#  'Rambling Rose',
#  'Reader',
#  'Rear Window',
#  'Rebel Without A Cause',
#  'Red Riding Hood',
#  'Reindeer Games',
#  'Relic',
#  'Remember Me',
#  'Replacements',
#  'Repo Man',
#  'Reservoir Dogs',
#  'Revenant',
#  'Revolutionary Road',
#  'Ringu',
#  'Rise of the Guardians',
#  'Rise of the Planet of the Apes',
#  'Road',
#  'Robin Hood Prince of Thieves',
#  'Rock',
#  'RocknRolla',
#  'Rocky',
#  'Rocky Horror Picture Show',
#  'Ronin',
#  'Roommate',
#  'Roughshod',
#  'Ruins',
#  'Runaway Bride',
#  'Rush',
#  'Rush Hour',
#  'Rush Hour 2',
#  'Rust and Bone',
#  'S Darko',
#  'Salton Sea',
#  'Sandlot Kids',
#  'Save the Last Dance',
#  'Saving Mr Banks',
#  'Saving Private Ryan',
#  'Saw',
#  'Scarface',
#  'Schindlers List',
#  'Scott Pilgrim vs the World',
#  'Scream',
#  'Scream 2',
#  'Scream 3',
#  'Se7en',
#  'Searchers',
#  'Secret Life of Walter Mitty',
#  'Semi Pro',
#  'Sense and Sensibility',
#  'Serenity',
#  'Serial Mom',
#  'Sessions',
#  'Seventh Seal',
#  'Sex and the City',
#  'Shakespeare in Love',
#  'Shallow Grave',
#  'Shame',
#  'Shawshank Redemption',
#  'Sherlock Holmes',
#  'Shes Out of My League',
#  'Shifty',
#  'Shining',
#  'Shipping News',
#  'Shivers',
#  'Shrek',
#  'Shrek the Third',
#  'Sicario',
#  'Sideways',
#  'Siege',
#  'Signs',
#  'Silence of the Lambs',
#  'Silver Bullet',
#  'Silver Linings Playbook',
#  'Simone',
#  'Single White Female',
#  'Sister Act',
#  'Six Degrees of Separation',
#  'Sleepy Hollow',
#  'Sling Blade',
#  'Slither',
#  'Slumdog Millionaire',
#  'Smashed',
#  'Smokin Aces',
#  'Snow Falling On Cedars',
#  'Snow White and the Huntsman',
#  'So I Married an Axe Murderer',
#  'Social Network',
#  'Solaris',
#  'Soldier',
#  'Someone To Watch Over Me',
#  'Source Code',
#  'South Park',
#  'Space Milkshake',
#  'Spare Me',
#  'Spartan',
#  'Speed Racer',
#  'Sphere',
#  'Spider Man',
#  'St Elmos Fire',
#  'Star Trek',
#  'Star Trek First Contact',
#  'Star Trek Generations',
#  'Star Trek II The Wrath of Khan',
#  'Star Trek Nemesis',
#  'Star Wars A New Hope',
#  'Star Wars Attack of the Clones',
#  'Star Wars Return of the Jedi',
#  'Star Wars The Empire Strikes Back',
#  'Star Wars The Force Awakens',
#  'Starman',
#  'Starship Troopers',
#  'State and Main',
#  'Station West',
#  'Sting',
#  'Stir of Echoes',
#  'Storytelling',
#  'Straight Outta Compton',
#  'Strange Days',
#  'Strangers on a Train',
#  'Stuntman',
#  'Sugar',
#  'Sunset Blvd',
#  'Sunshine Cleaning',
#  'Super 8',
#  'Superbad',
#  'Supergirl',
#  'Surfer King',
#  'Surrogates',
#  'Suspect Zero',
#  'Sweeney Todd The Demon Barber of Fleet Street',
#  'Sweet Hereafter',
#  'Sweet Smell of Success',
#  'Swordfish',
#  'Synecdoche New York',
#  'Syriana',
#  'TMNT',
#  'TRON',
#  'TRON Legacy',
#  'Take Shelter',
#  'Taking Sides',
#  'Taking of Pelham One Two Three',
#  'Talented Mr Ripley',
#  'Tall in the Saddle',
#  'Tamara Drewe',
#  'Taxi Driver',
#  'Ted',
#  'Terminator',
#  'Terminator 2 Judgement Day',
#  'Terminator Salvation',
#  'The Rage Carrie 2',
#  'Theory of Everything',
#  'Thing',
#  'Thirteen Days',
#  'This Boys Life',
#  'Thor',
#  'Thor Ragnarok',
#  'Three Kings',
#  'Three Men and a Baby',
#  'Three Musketeers',
#  'Thunderbirds',
#  'Thunderheart',
#  'Ticker',
#  'Timber Falls',
#  'Time Machine',
#  'Tin Cup',
#  'Tin Men',
#  'Tinker Tailor Soldier Spy',
#  'To Sleep with Anger',
#  'Tombstone',
#  'Tomorrow Never Dies',
#  'Total Recall',
#  'Tourist',
#  'Traffic',
#  'Transformers The Movie',
#  'Tristan and Isolde',
#  'Tropic Thunder',
#  'True Lies',
#  'Truman Show',
#  'Twilight',
#  'Twilight New Moon',
#  'Twin Peaks',
#  'Twins',
#  'Two For The Money',
#  'U Turn',
#  'Ugly Truth',
#  'Un Singe en Hiver',
#  'Unbreakable',
#  'Under Fire',
#  'Unknown',
#  'Up in the Air',
#  'V for Vendetta',
#  'Valkyrie',
#  'Verdict',
#  'Very Bad Things',
#  'Virtuosity',
#  'Visitor',
#  'Wag the Dog',
#  'Walk to Remember A',
#  'Walking Tall',
#  'Wall E',
#  'Wall Street',
#  'Wall Street Money Never Sleeps',
#  'Wanted',
#  'War Horse',
#  'War for the Planet of the Apes',
#  'Warm Springs',
#  'Watchmen',
#  'Water for Elephants',
#  'Way Back',
#  'We Own the Night',
#  'What Lies Beneath',
#  'When a Stranger Calls',
#  'While She Was Out',
#  'Whistleblower',
#  'White Christmas',
#  'White Jazz',
#  'White Ribbon',
#  'White Squall',
#  'Whiteout',
#  'Whos Your Daddy',
#  'Wild At Heart',
#  'Wild Bunch',
#  'Wild Hogs',
#  'Wild Things',
#  'Wild Things Diamonds in the Rough',
#  'Wild Wild West',
#  'Willow',
#  'Win Win',
#  'Wind Chill',
#  'Withnail and I',
#  'Wizard of Oz',
#  'Wolf of Wall Street',
#  'Wonder Boys',
#  'Wonder Woman',
#  'Woodsman',
#  'World is not Enough',
#  'Wrestler',
#  'X Files Fight the Future',
#  'X Men Origins Wolverine',
#  'Year One',
#  'Yes Man',
#  'You Can Count On Me',
#  'Youth in Revolt',
#  'Zero Dark Thirty',
#  'Zerophilia',
#  'Zootopia',
#  'xXx'}

# %%
movie_char_big_five_predict_result = movie_char_big_five_predict_result.sort_values(by=['movie_name', 'char'])

# %%
movie_char_big_five_predict_result.to_csv('movie_char_big_five_predict_result_organized.csv', index=False)
